# %% [markdown]
# <a href="https://colab.research.google.com/github/klnsuman/LangChain/blob/main/Embeddings_LangChain.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
import os
import sys
sys.path.append("/content/drive/MyDrive/colab_env/lib/python3.10/site-packages")
import os
import getpass

os.environ['OPENAI_API_KEY'] = getpass.getpass('OpenAI API Key:')
# Out:
# Mounted at /content/drive
# OpenAI API Key:··········

# %%
from langchain.embeddings import OpenAIEmbeddings
embeddings = OpenAIEmbeddings()

# %%
Text = "I Love India"
text_embeddings = embeddings.embed_query(Text)
print("len is",len(text_embeddings))
print(text_embeddings)
# Out:
# len is 1536
# ...
